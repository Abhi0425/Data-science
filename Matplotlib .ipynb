# %% [markdown]
# ans 1
# Matplotlib is a cross-platform, data visualization and graphical plotting library (histograms, scatter plots, bar charts,  for Python and its numerical extension NumPy
# 1 - histogram plot
# 2- bar plot
# 3- scatter plot
# 4- area plot
# 5- pie plot

# %%
#ans 2
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.plot(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Random Chart")
# Out:
# Text(0.5, 1.0, 'Random Chart')

# %% [markdown]
# ans 3
# The subplot() function takes three arguments that describes the layout of the figure.

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2,2,1)
plt.plot(x1,y1 ,'g*--')

plt.show()

x2 = np.array([0, 1, 2, 3, 4, 5])
y2= np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2,2,2)
plt.plot(x2,y2 , 'r^--')
plt.show()


x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,2,3)
plt.plot(x3,y3 , 'o')
plt.show()

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,4)
plt.plot(x4,y4 , 'y')
plt.show()

# %% [markdown]
# ###

# %% [markdown]
# ans4
# A barplot (or barchart) is one of the most common types of graphic.
# It shows the relationship between a numeric and a categoric variable.
# Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.
# It allows you to compare different sets of data among different groups easily.
# It instantly demonstrates this relationship using two axes, where the categories are on one axis and the various
# values are on the other.
# A bar graph can also illustrate important changes in data throughout a period of time.25-Aug-2022###

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company , profit)
plt.title("Company's Profit")
# Out:
# Text(0.5, 1.0, "Company's Profit")

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.barh(company , profit,height=0.8)
plt.title("Company's Profit")
# Out:
# Text(0.5, 1.0, "Company's Profit")

# %% [markdown]
#  ans-5  -
#  A box plot is a special type of diagram that shows the quartiles in a box and the line extending from the lowest
# to the highest value.
# Box plots are used to show distributions of numeric data values, especially when you want to
# compare them between multiple groups. They are built to provide high-level information at a glance,
# offering general information about a group of data's symmetry, skew, variance, and outliers

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.boxplot
plt.plot(box1, box2)
plt.title("RandomData")
# Out:
# Text(0.5, 1.0, 'RandomData')
